# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-5, 5, 101)

# %%
a = 1
b = 1
y = a*np.exp(-((x+2.5)**2)/b)

# %%
plt.plot(x, y)

# %%
sp = np.fft.fft(y)
freq = np.fft.fftfreq(x.shape[-1])
plt.plot(freq, sp.real**2, freq, sp.imag)

# %%
from photonics.Transform import Transform

# %%
t = Transform()
t.x = np.linspace(-5, 5, 101)
t.y = np.exp(-(t.x**2))

# %%
t.plot('test_plot.png')

# %%
t.fft('test_fft_plot.png')
